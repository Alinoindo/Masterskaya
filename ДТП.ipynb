# %% [markdown]
# <a href="https://colab.research.google.com/github/Alinoindo/Masterskaya/blob/main/%D0%94%D0%A2%D0%9F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install geopandas

# %%
import geopandas as gpd

# %%
# Чтение GeoJSON файла
gdf = gpd.read_file('amurskaia-oblast.geojson')

# Просмотр данных в табличном формате
print(gdf.head())  # первые 5 строк

# Если хотите увидеть все данные
print(gdf)
# Out:
# WARNING:pyogrio._io:Skipping field tags: unsupported OGR type: 5
# WARNING:pyogrio._io:Skipping field weather: unsupported OGR type: 5
# WARNING:pyogrio._io:Skipping field road_conditions: unsupported OGR type: 5
# WARNING:pyogrio._io:Skipping field participant_categories: unsupported OGR type: 5
#        id                                        light  \
# 0  189193                          Светлое время суток
# 1  189353                          Светлое время суток
# 2  189548                          Светлое время суток
# 3  188700  В темное время суток, освещение отсутствует
# 4  188702  В темное время суток, освещение не включено
#
#                                                point  \
# 0  { "lat": 49.800305000000002, "long": 129.84051...
# 1    { "lat": 49.130000000000003, "long": 129.1489 }
# 2  { "lat": 49.789873999999998, "long": 129.84691...
# 3  { "lat": 49.755600000000001, "long": 129.29220...
# 4  { "lat": 49.787187000000003, "long": 129.81648...
#
# ...
